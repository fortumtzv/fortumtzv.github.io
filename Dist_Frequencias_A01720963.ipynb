# %%
import pandas as pd
df = pd.DataFrame()
datos = [6.5,5.0,5.6,7.6,4.8,8.0,7.5,7.9,8.0,9.2,6.4,6.0,5.6,6.0,5.7,9.2,8.1,8.0,6.5,6.6,5.0,8.0,6.5,6.1,6.4,6.6,7.2,5.9,4.0,5.7,7.9,6.0,5.6,6.0,6.2,7.7,6.7,7.7,8.2,9.0]
df['datos'] = datos

# %%
import numpy as np 
import matplotlib.pyplot as plt
hist, bin_edges = np.histogram(datos, 40)
plt.hist(datos, bins=bin_edges)
plt.title("Histograma fi")
plt.show()
poligono = np.random.rand(40)*100
poligono.sort()
plt.title("Poligono de Frecuencias pi")
plt.plot(nivel1,datos)
